# %% [markdown]
# <a href="https://colab.research.google.com/github/CJLEGEND/fa5programactivity/blob/main/fa5program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def totprice (price, quantity):
    return float(price) * float(quantity)

x = (input("Enter the price of the item: "))
y = (input("Enter the number of items: "))
print ("The total price is:", totprice(x,y))
# Out:
# Enter the price of the item: 60
# Enter the number of items: 9
# The total price is: 540.0
